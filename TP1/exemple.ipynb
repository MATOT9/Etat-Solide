# %%
import TDS_H24_V2 as tds

hs = tds.HardSphere(scale=1)
hs.p # get momentum
# hs.p2  # get p^2
# hs.vel # get particles velocity
# hs.run() # run simulation
# Out:
# array([[-2.40207526e-26,  2.83640784e-24],
#        [-1.35097125e-23, -2.22752068e-25],
#        [-4.05512265e-25, -3.54159987e-24],
#        [-4.49928175e-24,  5.46076059e-24],
#        [-9.54494122e-24, -2.43640597e-23],
#        [ 1.30430208e-23,  6.33673251e-24],
#        [-1.71086224e-23, -1.22858708e-23],
#        [-1.81253666e-23,  4.69970156e-24],
#        [ 4.36078670e-24, -3.02800026e-24],
#        [ 4.83518137e-24, -8.44106590e-24],
#        [ 7.65108062e-24, -1.52934758e-23],
#        [-4.43854898e-24,  1.11763593e-24],
#        [-1.45866239e-23, -5.73162054e-24],
#        [-1.87302081e-23, -3.08665262e-24],
#        [ 5.24058707e-24,  6.37772390e-25],
#        [-4.86433497e-24, -6.54331982e-24],
#        [-4.15853502e-24, -5.19522443e-24],
#        [-4.22776643e-24, -1.48483770e-23],
#        [-1.24057055e-25, -8.88561023e-24],
#        [-1.04193454e-23,  1.22343579e-23],
#        [ 4.83615645e-24, -6.38348092e-24],
#        [-6.10520631e-24, -1.85824229e-23],
# ...

# %%
# to disable animation since normal speed is way to fast to be seen
hs.run(anim=False)

# hs.run() # run with animation

# %%
hs.p2
# Out:
# array([8.04578642e-48, 1.82561951e-46, 1.27073698e-47, 5.00634425e-47,
#        6.84713310e-46, 2.10274571e-46, 4.43647581e-46, 3.50616110e-46,
#        2.81852462e-47, 9.46305723e-47, 2.92429437e-46, 2.09498271e-47,
#        2.45621071e-46, 3.60348120e-46, 2.78705064e-47, 6.64767890e-47,
#        4.42837705e-47, 2.38348310e-46, 7.89694594e-47, 2.58242272e-46,
#        6.41372379e-47, 3.82579985e-46, 3.12593939e-46, 4.31775203e-46,
#        2.68317226e-47, 4.18398321e-47, 5.74865480e-46, 9.14051103e-47,
#        2.12037509e-46, 1.62830063e-46, 3.51715441e-46, 8.78118821e-46,
#        1.23266906e-46, 1.02982554e-46, 2.04675252e-46, 7.39309886e-47,
#        5.87239957e-47, 4.94170517e-46, 2.78093432e-46, 1.79521756e-47,
#        6.74490478e-47, 1.17924325e-46, 3.02012537e-48, 3.04560770e-48,
#        2.62027548e-46, 1.90387019e-46, 2.02663299e-46, 1.02565530e-46,
#        4.36963468e-46, 1.96614444e-46, 4.02599482e-46, 9.06071987e-47,
# ...
